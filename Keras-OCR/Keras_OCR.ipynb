# %%
# !pip install keras-ocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 831.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 53.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 37.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.8 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import keras_ocr
import cv2

# %%
def plot_img(img_path):
  img = cv2.imread(img_path)
  plt.imshow(img, cmap='gray')
  plt.show()

# %%
# keras-ocr will automatically download pretrained
# weights for the detector and recognizer.
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
import keras_ocr
import matplotlib.pyplot as plt

img_paths = []
for i in range(8):
  img_paths.append("/content/" + str(i+1) + ".jpg")

ocr_keras = keras_ocr.pipeline.Pipeline()
ocr_img_keras = [keras_ocr.tools.read(ocr_img_keras) for ocr_img_keras in img_paths]
ocr_pred = ocr_keras.recognize(ocr_img_keras)
fig, axs = plt.subplots(nrows=len(ocr_img_keras), figsize=(10, 20))

for ax, image, predictions in zip(axs, ocr_img_keras, ocr_pred):
  keras_ocr.tools.drawAnnotations(image=image,
                                  predictions=predictions,
                                  ax=ax)
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# ...
# 5/5 [==============================] - 37s 7s/step
